# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('res_.csv')
df.drop(columns=['train_count', 'Unnamed: 0'], inplace=True)

# %%
df
# Out:
#     frac_train  test_accuracy  test_mean_prec_macro  test_mean_recall_macro
# 0         0.01       0.595000              0.253042                0.254830
# 1         0.01       0.521667              0.281517                0.334561
# 2         0.01       0.570000              0.316453                0.274098
# 3         0.05       0.768333              0.561907                0.445202
# 4         0.05       0.743333              0.494145                0.410018
# 5         0.05       0.781667              0.462489                0.445797
# 6         0.10       0.793333              0.554284                0.486761
# 7         0.10       0.766667              0.485608                0.453269
# 8         0.10       0.778333              0.532340                0.470169
# 9         0.20       0.760000              0.512396                0.510044
# 10        0.20       0.788333              0.563267                0.571580
# ...

# %%
fig, ax = plt.subplots(figsize=(12, 9))
sns.set_theme()
sns.axes_style("darkgrid")
plot = sns.lineplot('frac_train', 'value', data=pd.melt(df, 'frac_train'), 
                    hue='variable', marker='o', ax=ax)
plot.legend(loc='lower right')

ax.set_xlabel("Fraction of training set")
ax.set_ylabel("Score")
ax.set_title("Average Results over 3 Runs Per Split")
plt.savefig('avg_runs.png')
# Out:
# /home/kaipak/miniconda3/envs/pytorch/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
pd.melt(df, 'frac_train')
# Out:
#     frac_train                variable     value
# 0         0.01           test_accuracy  0.595000
# 1         0.01           test_accuracy  0.521667
# 2         0.01           test_accuracy  0.570000
# 3         0.05           test_accuracy  0.768333
# 4         0.05           test_accuracy  0.743333
# 5         0.05           test_accuracy  0.781667
# 6         0.10           test_accuracy  0.793333
# 7         0.10           test_accuracy  0.766667
# 8         0.10           test_accuracy  0.778333
# 9         0.20           test_accuracy  0.760000
# 10        0.20           test_accuracy  0.788333
# 11        0.20           test_accuracy  0.788333
# 12        0.50           test_accuracy  0.805000
# 13        0.50           test_accuracy  0.793333
# 14        0.50           test_accuracy  0.815000
# 15        0.90           test_accuracy  0.820000
# 16        0.90           test_accuracy  0.815000
# 17        0.90           test_accuracy  0.800000
# ...

# %%
df.iloc[:, :]
# Out:
#     frac_train  train_count  test_accuracy  test_mean_prec_macro  \
# 0         0.01           57       0.595000              0.253042
# 1         0.01           57       0.521667              0.281517
# 2         0.01           57       0.570000              0.316453
# 3         0.05          292       0.768333              0.561907
# 4         0.05          292       0.743333              0.494145
# 5         0.05          292       0.781667              0.462489
# 6         0.10          588       0.793333              0.554284
# 7         0.10          588       0.766667              0.485608
# 8         0.10          588       0.778333              0.532340
# 9         0.20         1177       0.760000              0.512396
# 10        0.20         1177       0.788333              0.563267
# 11        0.20         1177       0.788333              0.574602
# 12        0.50         2960       0.805000              0.619964
# ...
